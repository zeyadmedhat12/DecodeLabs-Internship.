# %%
import pandas as pd

# %%
d = pd.read_csv('Dataset for Data Analytics.csv')
d.head()
# data imported successfully

# %%
d.shape
# number of imported columns and rows is correct

# %%
d.describe

# %%
d.info

# %%
d.isna().sum()
# there are 309 missing values in CouponCode

# %%
d["CouponCode"] = d["CouponCode"].fillna(d["CouponCode"].mode()[0])

# %%
d.isna().sum()
# missing values are replaced with mode (most repeated)

# %%
d.duplicated().sum()
# no duplicates are found

# %%
d.dtypes

# %%
d["Date"] = pd.to_datetime(d["Date"])


cat_cols = ["Product", "PaymentMethod", "OrderStatus", "ReferralSource"]
for col in cat_cols:
    d[col] = d[col].astype("category")

# %%
d.dtypes
